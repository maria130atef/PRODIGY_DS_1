# %%
import pandas as pd

df = pd.read_csv("/content/API_SP.POP.TOTL_DS2_en_csv_v2_6224560.csv", skiprows=4)
df = df.drop("Unnamed: 67", axis=1)
# Out:
#                    Country Name Country Code     Indicator Name  \
# 0                         Aruba          ABW  Population, total
# 1   Africa Eastern and Southern          AFE  Population, total
# 2                   Afghanistan          AFG  Population, total
# 3    Africa Western and Central          AFW  Population, total
# 4                        Angola          AGO  Population, total
# 5                       Albania          ALB  Population, total
# 6                       Andorra          AND  Population, total
# 7                    Arab World          ARB  Population, total
# 8          United Arab Emirates          ARE  Population, total
# 9                     Argentina          ARG  Population, total
# 10                      Armenia          ARM  Population, total
# 11               American Samoa          ASM  Population, total
# 12          Antigua and Barbuda          ATG  Population, total
# 13                    Australia          AUS  Population, total
# ...

# %%
df.head(70)
# Out:
#                    Country Name Country Code     Indicator Name  \
# 0                         Aruba          ABW  Population, total
# 1   Africa Eastern and Southern          AFE  Population, total
# 2                   Afghanistan          AFG  Population, total
# 3    Africa Western and Central          AFW  Population, total
# 4                        Angola          AGO  Population, total
# ..                          ...          ...                ...
# 65        Europe & Central Asia          ECS  Population, total
# 66                      Ecuador          ECU  Population, total
# 67             Egypt, Arab Rep.          EGY  Population, total
# 68                    Euro area          EMU  Population, total
# 69                      Eritrea          ERI  Population, total
#
#    Indicator Code         1960         1961         1962         1963  \
# 0     SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
l=range(55,67)
y=df.iloc[67, l]
y=list(y)
print(y)
# Out:
# [89200054.0, 91240376.0, 93377890.0, 95592324.0, 97723799.0, 99784030.0, 101789386.0, 103740765.0, 105618671.0, 107465134.0, 109262178.0, 110990103.0]

# %%
x=df.columns
x=list(x[55:67])

# %%
import matplotlib.pyplot as plt

plt.ylabel('population mi')
plt.xlabel('years')
plt.title('population of Egypt last 12 years')
plt.bar(x,y)
plt.show()
